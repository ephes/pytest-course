# %%
from mastodon import Mastodon

# %%
client.secret
# Out:
# ''

# %%
client = Client.objects.get(api_base_url="https://fedi.python-podcast.de")
mastodon = Mastodon(api_base_url=client.api_base_url)

# %%
mastodon.timeline_local()
# Out:
# [{'id': 176899166336291816,
#   'uri': 'https://fedi.python-podcast.de/@show@python-podcast.de/posts/176899166336291816/',
#   'created_at': datetime.datetime(2023, 5, 4, 10, 34, 7, 882000, tzinfo=tzlocal()),
#   'account': {'id': 2,
#    'username': 'show',
#    'acct': 'show@python-podcast.de',
#    'url': 'https://fedi.python-podcast.de/@show/',
#    'display_name': 'Python Podcast',
#    'note': 'Ein deutschsprachiger Podcast rund um die Programmiersprache Python.',
#    'avatar': 'https://fedi.python-podcast.de/media/profile_images/2022/12/15/LCs6mybM6jADNHeubQQTPKSFZRw.jpeg',
#    'avatar_static': 'https://fedi.python-podcast.de/media/profile_images/2022/12/15/LCs6mybM6jADNHeubQQTPKSFZRw.jpeg',
#    'header': 'https://fedi.python-podcast.de/media/background_images/2022/12/15/emwFN2GEk9FNMWgKk0iui_5M7zE.png',
#    'header_static': 'https://fedi.python-podcast.de/media/background_images/2022/12/15/emwFN2GEk9FNMWgKk0iui_5M7zE.png',
#    'locked': False,
#    'fields': [],
# ...
